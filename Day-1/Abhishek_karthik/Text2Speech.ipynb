# %%
# !pip install gTTS
# Out:
# ...
#   Stored in directory: C:\Users\Abhishek karthik\AppData\Local\pip\Cache\wheels\dd\11\61\33f7e51bf545e910552b2255eead2a7cd8ef54064b46dceb34
# Successfully built gtts-token
# ...

# %%
from gtts import gTTS 
import os

# %%
text = "It is a very beautiful day"

# %%
language = 'en'

# %%
speech = gTTS(text = text, lang = language, slow = False)

# %%
speech.save("sample.mp3")

# %%
os.system("sample.mp3")
# Out:
# 0
